# %% [markdown]
# <a href="https://colab.research.google.com/github/claudio1975/100DataScienceProjects/blob/master/An%20Experimental%20Exploratory%20Data%20Analysis%20Pipeline/An_Experimental_EDA_for_a_regression_task_auto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **An Experimental Exploratory Data Analysis for a regression task**
# ### ****From Visualization to Statistical Analysis****
# ### ****From Feature Engineering to Feature Selection****
# ### ****From the Best Model Selection to Interpretability****
#
# Exploratory Data Analysis is the first step in the Machine Learning Pipeline used to analyze data and it's between data cleaning and data modelling steps in the Data Science Pipeline. The reasons why you can use EDA are: understand patterns; detect mistakes; check assumptions; check relationships between variables of a dataset using visualization tools and statistical analysis.
# The goal of this step is to show a package for an automated EDA.

# %% [markdown]
# ### ****Prepare Workspace****
# To start the exploration set up the environment with libraries, upload the dataset (it's stored in a github repository) and split it into target variable and features variables. No more set up is required using Google Colab. Look at the guidelines: https://colab.research.google.com/notebooks/welcome.ipynb

# %%
# Upload libraries
import pandas as pd
import pandas_profiling as pp

# %%
# Upload dataset
url ='https://raw.githubusercontent.com/claudio1975/100DataScienceProjects/master/An%20Experimental%20Exploratory%20Data%20Analysis%20Pipeline/data/NYC_Taxi_Trip_train.csv'
df = pd.read_csv(url)

# %% [markdown]
# ![](https://lh5.googleusercontent.com/proxy/nLNUERRp6QG9BMbADEtySxKSmxIbgNUDTUUdrSpvcts4o4nQizpMpdlZIaEWTOZVPYHS7sIFhOYxSzNJGm_i4sYtJ4vG4EJqZhblzg=w1200-h630-p-k-no-nu)

# %% [markdown]
# ### ***Automated Explorative Data Analysis***

# %%
pp.ProfileReport(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %% [markdown]
# ### *References*
# https://www.kaggle.com/prashant111/eda-is-fun
